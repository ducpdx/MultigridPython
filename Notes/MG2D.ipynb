# %%
'''
import Python libraries and presets
'''
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('../FigStyle/plot.mplstyle')

# %%
'''
ROUNTINES FOR DATASTRUCTURE
'''
def initialize(nx0, ny0, maxlevel, xa, xb, ya, yb):
    ii    = np.array([nx0*(2**i) for i in range(maxlevel)])
    jj    = np.array([ny0*(2**i) for i in range(maxlevel)])    
    hx    = (xb-xa)*1./ii 
    hy    = (yb-ya)*1./jj
    f     = np.array([np.zeros((ii[k]+1, jj[k]+1)) for k in range(maxlevel)], 
             dtype=np.ndarray)
    u     = np.array([np.zeros((jj[k]+1, ii[k]+1)) for k in range(maxlevel)], 
             dtype=np.ndarray)
    uold  = np.array([np.zeros((ii[k]+1, jj[k]+1)) for k in range(maxlevel)], 
             dtype=np.ndarray)
    uconv = np.array([np.zeros((ii[k]+1, jj[k]+1)) for k in range(maxlevel)], 
             dtype=np.ndarray)
    return ii,jj,hx,hy,f,u,uold,uconv

# %%
'''
FUNCTIONS
'''
def U_a(x,y):
    #analytical solution
    return np.sin(2*np.pi*x)*np.sin(2*np.pi*y)
def U_b(x,y):
    #take analytical solution as boundary condition
    return np.sin(2*np.pi*x)*np.sin(2*np.pi*y)
def U_i(x,y):
    #initial approximation
    return 0.0
def F_i(x,y,EPSILON):
    #right hand side function
    return -4*(1+EPSILON)*np.pi**2*np.sin(2*np.pi*x)*np.sin(2*np.pi*y)
def Lu(u, rhx2, rhy2, i, j, EPSILON): 
    #compute operator in point i,j  
    return(rhx2*(u[i-1][j  ]-2*u[i][j]+u[i+1][j  ])\
          +rhy2*(u[i  ][j-1]-2*EPSILON*u[i][j]+u[i  ][j+1]))

# %%
'''
SINGLE GRID ROUTINES
'''
def init_uf(u, f, k, ii, jj, xa, ya, hx, hy, EPSILON):
    '''
    initialize u, sets boundary condition for u, and 
    initialize right hand side values on grid level
    '''
    x = 0.0
    y = 0.0
    for i in range(ii[k]):
        x = xa + i*hx[k]
        for j in range(jj[k]):
            y = ya + j*hx[k]
            if ((i==0) or (j==0) or (i==ii[k]) or (j==jj[k])):
                u[k][i][j]=U_b(x,y)
            else:
                u[k][i][j]=U_i(x,y)
            f[k][i][j] = F_i(x,y,EPSILON)
    return u,f

def relax(u, f, k, ii, jj, hx, hy, wu, EPSILON):
    #perform Gauss-Seidel relaxation on gridlevel k 
    rhx2 = 1.0/(hx[k]*hx[k]); 
    rhy2 = 1.0/(hy[k]*hy[k]);
    
    for i in range (1,ii[k]): 
        for j in range (1,jj[k]): 
            u[k][i][j] += (f[k][i][j]-Lu(u[k],rhx2,rhy2,i,j, EPSILON))/(-2*rhx2-2*rhy2)
  
    err = 0.0 
    for i in range (1,ii[k]): 
        for j in range (1,jj[k]): 
            err += np.fabs(f[k][i][j]-Lu(u[k],rhx2,rhy2,i,j,EPSILON))

    wu += np.exp((maxlevel-k-1)*np.log(.25))
    print("\nLevel %d Residual %8.5e Wu %8.5e"%(k+1, err/((ii[k]-1)*(jj[k]-1)),wu))
    return u, wu

def conver_a(u, k, ii, jj, xa, ya, hx, hy): 
    '''
    compute L1 norm of difference between U and analytic solution 
    on level k
    '''
    
    err = 0.0
    
    for i in range (1,ii[k]): 
        x = xa + i*hx[k]
        for j in range (1,jj[k]):
            y = ya + j*hx[k]
            err += np.fabs(u[k][i][j]-U_a(x,y))
    
    return (err/((ii[k]-1)*(jj[k]-1)))

# %%
'''
INTER GRID ROUTINES
'''
def coarsen_u(u, uold, k, ii, jj, hx, hy, wu, EPSILON):
    '''
    compute initial approximation on level k-1 
    in coarsening step from level k
    '''
    
    iic = ii[k-1]
    jjc = jj[k-1]
    
    for ic in range (1,iic): 
        for jc in range (1,jjc):
            u[k-1][ic][jc] = .0625*(     u[k][2*ic-1][2*jc-1]+u[k][2*ic-1][2*jc+1]\
                                        +u[k][2*ic+1][2*jc-1]+u[k][2*ic+1][2*jc+1]\
                                   +2.0*(u[k][2*ic-1][2*jc  ]+u[k][2*ic+1][2*jc  ]\
                                   +     u[k][2*ic  ][2*jc-1]+u[k][2*ic  ][2*jc+1])\
                                   + 4.0*u[k][2*ic  ][2*jc  ])

    #store coarse grid solution in uco array
    for ic in range (iic+1): 
        for jc in range (jjc+1):
            uold[k-1][ic][jc] = u[k-1][ic][jc]  
    return u,uold

def coarsen_f(u, f, k, ii, jj, hx, hy, wu, EPSILON):
    '''
    compute coarse grid right hand side on level k-1 
    in coarsening step from level k
    '''
    
    iic = ii[k-1]
    jjc = jj[k-1]
    
    rh2xc = 1.0/(hx[k-1]*hx[k-1])
    rh2yc = 1.0/(hy[k-1]*hy[k-1])
    
    rh2x  = 1.0/(hx[k]*hx[k]) 
    rh2y  = 1.0/(hy[k]*hy[k])
    
    for ic in range (1,iic): 
        for jc in range (1,jjc):
            rc  = (f[k][2*ic  ][2*jc  ] - Lu(u[k],rh2x,rh2y,2*ic  ,2*jc  ,EPSILON))
            rn  = (f[k][2*ic  ][2*jc+1] - Lu(u[k],rh2x,rh2y,2*ic  ,2*jc+1,EPSILON))
            re  = (f[k][2*ic+1][2*jc  ] - Lu(u[k],rh2x,rh2y,2*ic+1,2*jc  ,EPSILON))
            rs  = (f[k][2*ic  ][2*jc-1] - Lu(u[k],rh2x,rh2y,2*ic  ,2*jc-1,EPSILON))
            rw  = (f[k][2*ic-1][2*jc  ] - Lu(u[k],rh2x,rh2y,2*ic-1,2*jc  ,EPSILON))
            rne = (f[k][2*ic+1][2*jc+1] - Lu(u[k],rh2x,rh2y,2*ic+1,2*jc+1,EPSILON))
            rse = (f[k][2*ic+1][2*jc-1] - Lu(u[k],rh2x,rh2y,2*ic+1,2*jc-1,EPSILON))
            rsw = (f[k][2*ic-1][2*jc-1] - Lu(u[k],rh2x,rh2y,2*ic-1,2*jc-1,EPSILON))
            rnw = (f[k][2*ic-1][2*jc+1] - Lu(u[k],rh2x,rh2y,2*ic-1,2*jc+1,EPSILON))
            #FAS coarse grid right hand sie   
            #with full weighting of residuals 
            f[k-1][ic][jc] = Lu(u[k-1],rh2xc,rh2yc,ic,jc,EPSILON) \
                                +.0625*(rne+rse+rsw+rnw+2.0*(rn+re+rs+rw)+4.0*rc)    
    return f

def refine(u, uold, f, k, ii, jj, hx, hy, EPSILON):
    '''
    Interpolation and addition of coarse grid correction from grid k-1 
    to grid k   
    '''
    iic = ii[k-1]
    jjc = jj[k-1]

    for ic in range (1,iic+1): 
        for jc in range (1,jjc+1):
            if (ic<iic): 
                u[k][2*ic  ][2*jc  ] += (u[k-1][ic  ][jc]-uold[k-1][ic][jc])

            if (jc<jjc): 
                u[k][2*ic-1][2*jc  ] += (u[k-1][ic  ][jc]-uold[k-1][ic  ][jc]\
                                        +u[k-1][ic-1][jc]-uold[k-1][ic-1][jc])*0.5

            if (ic<iic):
                u[k][2*ic  ][2*jc-1] += (u[k-1][ic  ][jc  ]-uold[k-1][ic  ][jc  ]\
                                        +u[k-1][ic][jc-1  ]-uold[k-1][ic  ][jc-1])*0.5
                
            u[k][2*ic-1][2*jc-1]     += (u[k-1][ic  ][jc  ]-uold[k-1][ic  ][jc  ]\
                                        +u[k-1][ic][jc-1  ]-uold[k-1][ic  ][jc-1]\
                                        +u[k-1][ic-1][jc  ]-uold[k-1][ic-1][jc  ]\
                                        +u[k-1][ic-1][jc-1]-uold[k-1][ic-1][jc-1])*0.25
    return u

def fmg_interpolate(u, uconv, f, k, ii, jj, hx, hy, EPSILON):
    '''
    interpolation of coarse grid k-1 solution to fine grid 
    to serve as first approximation bi-cubic interpolation 
    '''
    iic = ii[k-1]
    jjc = jj[k-1]

    #store grid k-1 solution for later use in convergence check 

    for ic in range (1,iic): 
        for jc in range (1,jjc):
            uconv[k-1][ic][jc] = u[k-1][ic][jc]
    
    #first inject to points coinciding with coarse points
    for ic in range (1,iic): 
        for jc in range (1,jjc):
            u[k][2*ic][2*jc] = u[k-1][ic][jc]
            
    #interpolate intermediate y direction
    for i in range (2,ii[k]-1): 
        u[k][i][1]    = (5.0*u[k][i][0  ]+15.0*u[k][i][2   ]-5.0*u[k][i][4   ]+u[k][i][6   ])*.0625
        for j in range (3,jj[k]-2,2): 
            u[k][i][j]   = (-u[k][i][j-3]+9.0 *u[k][i][j-1 ]+9.0*u[k][i][j+1 ]-u[k][i][j+3 ])*.0625        
        u[k][i][jj[k]-1] = (5.0*u[k][i][jj[k]]+15.0*u[k][i][jj[k]-2]-5.0*u[k][i][jj[k]-4]+u[k][i][jj[k]-6])*.0625

    #interpolate in x direction 
    for j in range (1,jj[k]): 
        u[k][1][j]    = (5.0*u[k][0  ][j]+15.0*u[k][2   ][j]-5.0*u[k][4   ][j]+u[k][6   ][j])*.0625
        for i in range (3,ii[k]-2,2): 
            u[k][i][j]   = (-u[k][i-3][j]+9.0 *u[k][i-1 ][j]+9.0*u[k][i+1 ][j]-u[k][i+3 ][j])*.0625
        u[k][ii[k]-1][j] = (5.0*u[k][ii[k]][j]+15.0*u[k][ii[k]-2][j]-5.0*u[k][ii[k]-4][j]+u[k][ii[k]-6][j])*.0625    
    return u, uconv

def conver(u, uconv, k, maxlevel):
    '''
    convergence check using converged solution on level k 
    and on next coarser grid k-1
    '''
    
    iic = ii[k-1]
    jjc = jj[k-1]
    
    if (k==(maxlevel-1)):
        err = 0.0 
        for ic in range (1,iic): 
            for jc in range (1,jjc):
                err += np.fabs(uconv[k-1][ic][jc]-u[k][2*ic][2*jc])
    else:
        err = 0.0 
        for ic in range (1,iic): 
            for jc in range (1,jjc):
                err += np.fabs(uconv[k-1][ic][jc]-uconv[k][2*ic][2*jc])
    
    return (err/((iic-1)*(jjc-1)))

# %%
'''
MULTIGRID DRIVING ROUTINES
'''
def cycle(u, uold, f, k, wu, nu0, nu1, nu2, gamma, EPSILON):
    '''
    perform coarse grid correction cycle starting on level k  
    nu1 pre-relaxations, nu2 post relaxation, nu0 relaxations 
    on the coarest grid, cycleindex gamma=1 for Vcycle,       
    gamma=2 for Wcycle
    '''  
    if (k==0):#base case
        for i in range(nu0):
            [u,wu] = relax(u, f, k, ii, jj, hx, hy, wu, EPSILON)
    else:
        for i in range(nu1):        
            [u,wu]  = relax(u, f, k, ii, jj, hx, hy, wu, EPSILON)
        [u,uold]= coarsen_u(u, uold, k, ii, jj, hx, hy, wu, EPSILON)
        f = coarsen_f(u, f, k, ii, jj, hx, hy, wu, EPSILON)
        for i in range(gamma): 
            [u,wu] = cycle(u, uold, f, k-1, wu, nu0, nu1, nu2, gamma, EPSILON)
        u = refine(u, uold, f, k, ii, jj, hx, hy, EPSILON)
        for i in range(nu2):
            [u,wu]  = relax(u, f, k, ii, jj, hx, hy, wu, EPSILON)
    
    return u,wu

def fmg (u, uold, uconv, f, k, wu, maxlevel, nu0, nu1, nu2, gamma, ncy, EPSILON):
    '''
    perform FMG with k levels and ncy cycles per level

    '''  
    
    if (maxlevel==1):#base case
        for j in range(ncy):
            for i in range(nu0):
                [u,wu] = relax(u, f, k, ii, jj, hx, hy, wu, EPSILON)
    else:
        if (k==0):#base case
            for i in range(nu0):
                [u,wu] = relax(u, f, k, ii, jj, hx, hy, wu, EPSILON)
        else:
            [u, uconv, wu] = fmg (u, uold, uconv, f, k-1, wu, maxlevel, nu0, nu1, nu2, gamma, ncy, EPSILON)
            [u,uconv] = fmg_interpolate(u, uconv, f, k, ii, jj, hx, hy, EPSILON)
            for j in range(ncy):
                [u,wu] = cycle(u, uold, f, k, wu, nu0, nu1, nu2, gamma, EPSILON)
                print("\n")
    return u, uconv, wu

# %%
'''
MAIN PROGRAM
'''
#Stack
[nx0,ny0,xa,xb,ya,yb,wu] = [4,4,0.0,1.0,0.0,1.0,0.0]
#cycle parameters
[nu0,nu1,nu2,gamma]      = [10,2,1,1]
EPSILON  = 1
maxlevel = input('\ngive maxlevel: ')
ncy      = input('\ngive ncy: ') 
[ii,jj,hx,hy,f,u,uold,uconv] = initialize(nx0, ny0, maxlevel, xa, xb, ya, yb)
for k in range(maxlevel):
    [u,f] = init_uf(u, f, k, ii, jj, xa, ya, hx, hy, EPSILON) 
[u, uconv, wu] = fmg (u, uold, uconv, f, k, wu, maxlevel, nu0, nu1, nu2, gamma, ncy, EPSILON)
print("\n\nLevel %d: er=%10.8e\n\n"%(maxlevel,conver_a(u, maxlevel-1, ii, jj, xa, ya, hx, hy)))
if (maxlevel>1):
    print("\n")
    for j in range(1,maxlevel):
        print("\n aen(%2d,%2d)=%8.5e"%(j+1,j,conver(u, uconv, j, maxlevel)))
print("\n")
# Out:
# give maxlevel: 10
#
# give ncy: 1
#
# Level 1 Residual 1.03836e+01 Wu 3.81470e-06
#
# Level 1 Residual 3.67968e+00 Wu 7.62939e-06
#
# Level 1 Residual 9.48300e-01 Wu 1.14441e-05
#
# Level 1 Residual 2.10637e-01 Wu 1.52588e-05
#
# Level 1 Residual 1.22712e-01 Wu 1.90735e-05
#
# Level 1 Residual 6.35305e-02 Wu 2.28882e-05
#
# Level 1 Residual 3.20370e-02 Wu 2.67029e-05
#
# Level 1 Residual 1.60525e-02 Wu 3.05176e-05
#
# Level 1 Residual 8.03049e-03 Wu 3.43323e-05
#
# Level 1 Residual 4.01578e-03 Wu 3.81470e-05
#
# Level 2 Residual 6.97216e+00 Wu 5.34058e-05
#
# Level 2 Residual 3.41219e+00 Wu 6.86646e-05
#
# Level 1 Residual 7.30492e-01 Wu 7.24792e-05
#
# Level 1 Residual 3.14200e-01 Wu 7.62939e-05
#
# Level 1 Residual 9.46716e-02 Wu 8.01086e-05
#
# Level 1 Residual 3.02203e-02 Wu 8.39233e-05
#
# Level 1 Residual 1.66481e-02 Wu 8.77380e-05
#
# Level 1 Residual 8.51631e-03 Wu 9.15527e-05
#
# Level 1 Residual 4.28219e-03 Wu 9.53674e-05
#
# Level 1 Residual 2.14410e-03 Wu 9.91821e-05
#
# Level 1 Residual 1.07242e-03 Wu 1.02997e-04
#
# Level 1 Residual 5.36259e-04 Wu 1.06812e-04
#
# Level 2 Residual 9.15117e-01 Wu 1.22070e-04
#
#
#
# Level 3 Residual 1.93176e+00 Wu 1.83105e-04
#
# Level 3 Residual 1.49179e+00 Wu 2.44141e-04
#
# Level 2 Residual 8.41380e-01 Wu 2.59399e-04
#
# Level 2 Residual 5.03637e-01 Wu 2.74658e-04
#
# Level 1 Residual 1.24929e-01 Wu 2.78473e-04
#
# Level 1 Residual 3.99075e-02 Wu 2.82288e-04
#
# Level 1 Residual 1.48291e-02 Wu 2.86102e-04
#
# Level 1 Residual 6.90184e-03 Wu 2.89917e-04
#
# Level 1 Residual 3.64500e-03 Wu 2.93732e-04
#
# Level 1 Residual 1.84676e-03 Wu 2.97546e-04
#
# Level 1 Residual 9.26412e-04 Wu 3.01361e-04
#
# Level 1 Residual 4.63585e-04 Wu 3.05176e-04
#
# Level 1 Residual 2.31840e-04 Wu 3.08990e-04
#
# Level 1 Residual 1.15926e-04 Wu 3.12805e-04
#
# Level 2 Residual 1.17286e-01 Wu 3.28064e-04
#
# Level 3 Residual 2.49471e-01 Wu 3.89099e-04
#
#
#
# Level 4 Residual 5.26688e-01 Wu 6.33240e-04
#
# Level 4 Residual 4.85783e-01 Wu 8.77380e-04
#
# Level 3 Residual 4.12569e-01 Wu 9.38416e-04
#
# Level 3 Residual 3.51605e-01 Wu 9.99451e-04
#
# Level 2 Residual 2.12394e-01 Wu 1.01471e-03
#
# Level 2 Residual 1.26389e-01 Wu 1.02997e-03
#
# Level 1 Residual 3.04891e-02 Wu 1.03378e-03
#
# Level 1 Residual 9.25946e-03 Wu 1.03760e-03
#
# Level 1 Residual 3.63189e-03 Wu 1.04141e-03
#
# Level 1 Residual 1.77761e-03 Wu 1.04523e-03
#
# Level 1 Residual 9.34452e-04 Wu 1.04904e-03
#
# Level 1 Residual 4.72932e-04 Wu 1.05286e-03
#
# Level 1 Residual 2.37179e-04 Wu 1.05667e-03
#
# Level 1 Residual 1.18679e-04 Wu 1.06049e-03
#
# Level 1 Residual 5.93506e-05 Wu 1.06430e-03
#
# Level 1 Residual 2.96767e-05 Wu 1.06812e-03
#
# Level 2 Residual 2.85485e-02 Wu 1.08337e-03
#
# Level 3 Residual 5.77443e-02 Wu 1.14441e-03
#
# Level 4 Residual 6.84303e-02 Wu 1.38855e-03
#
#
#
# Level 5 Residual 1.38567e-01 Wu 2.36511e-03
#
# Level 5 Residual 1.35141e-01 Wu 3.34167e-03
#
# Level 4 Residual 1.29743e-01 Wu 3.58582e-03
#
# Level 4 Residual 1.23797e-01 Wu 3.82996e-03
#
# Level 3 Residual 1.09725e-01 Wu 3.89099e-03
#
# Level 3 Residual 9.42013e-02 Wu 3.95203e-03
#
# Level 2 Residual 5.71510e-02 Wu 3.96729e-03
#
# Level 2 Residual 3.37806e-02 Wu 3.98254e-03
#
# Level 1 Residual 7.98565e-03 Wu 3.98636e-03
#
# Level 1 Residual 2.41763e-03 Wu 3.99017e-03
#
# Level 1 Residual 9.50566e-04 Wu 3.99399e-03
#
# Level 1 Residual 4.66321e-04 Wu 3.99780e-03
#
# Level 1 Residual 2.45085e-04 Wu 4.00162e-03
#
# Level 1 Residual 1.24033e-04 Wu 4.00543e-03
#
# Level 1 Residual 6.22029e-05 Wu 4.00925e-03
#
# Level 1 Residual 3.11247e-05 Wu 4.01306e-03
#
# Level 1 Residual 1.55653e-05 Wu 4.01688e-03
#
# Level 1 Residual 7.78300e-06 Wu 4.02069e-03
#
# Level 2 Residual 7.56168e-03 Wu 4.03595e-03
#
# Level 3 Residual 1.54975e-02 Wu 4.09698e-03
#
# Level 4 Residual 1.74303e-02 Wu 4.34113e-03
#
# Level 5 Residual 1.79385e-02 Wu 5.31769e-03
#
#
#
# Level 6 Residual 3.55860e-02 Wu 9.22394e-03
#
# Level 6 Residual 3.52897e-02 Wu 1.31302e-02
#
# Level 5 Residual 3.50319e-02 Wu 1.41068e-02
#
# Level 5 Residual 3.45187e-02 Wu 1.50833e-02
#
# Level 4 Residual 3.36636e-02 Wu 1.53275e-02
#
# Level 4 Residual 3.22646e-02 Wu 1.55716e-02
#
# Level 3 Residual 2.87897e-02 Wu 1.56326e-02
#
# Level 3 Residual 2.47419e-02 Wu 1.56937e-02
#
# Level 2 Residual 1.50078e-02 Wu 1.57089e-02
#
# Level 2 Residual 8.83374e-03 Wu 1.57242e-02
#
# Level 1 Residual 2.08088e-03 Wu 1.57280e-02
#
# Level 1 Residual 6.27928e-04 Wu 1.57318e-02
#
# Level 1 Residual 2.47462e-04 Wu 1.57356e-02
#
# Level 1 Residual 1.21663e-04 Wu 1.57394e-02
#
# Level 1 Residual 6.39302e-05 Wu 1.57433e-02
#
# Level 1 Residual 3.23524e-05 Wu 1.57471e-02
#
# Level 1 Residual 1.62246e-05 Wu 1.57509e-02
#
# Level 1 Residual 8.11837e-06 Wu 1.57547e-02
#
# Level 1 Residual 4.05994e-06 Wu 1.57585e-02
#
# Level 1 Residual 2.03006e-06 Wu 1.57623e-02
#
# Level 2 Residual 1.96917e-03 Wu 1.57776e-02
#
# Level 3 Residual 4.07697e-03 Wu 1.58386e-02
#
# Level 4 Residual 4.55914e-03 Wu 1.60828e-02
#
# Level 5 Residual 4.58347e-03 Wu 1.70593e-02
#
# Level 6 Residual 4.61112e-03 Wu 2.09656e-02
#
#
#
# Level 7 Residual 9.01135e-03 Wu 3.65906e-02
#
# Level 7 Residual 8.98351e-03 Wu 5.22156e-02
#
# Level 6 Residual 8.98446e-03 Wu 5.61218e-02
#
# Level 6 Residual 8.94267e-03 Wu 6.00281e-02
#
# Level 5 Residual 8.92588e-03 Wu 6.10046e-02
#
# Level 5 Residual 8.81133e-03 Wu 6.19812e-02
#
# Level 4 Residual 8.62215e-03 Wu 6.22253e-02
#
# Level 4 Residual 8.27233e-03 Wu 6.24695e-02
#
# Level 3 Residual 7.38664e-03 Wu 6.25305e-02
#
# Level 3 Residual 6.34765e-03 Wu 6.25916e-02
#
# Level 2 Residual 3.84667e-03 Wu 6.26068e-02
#
# Level 2 Residual 2.25900e-03 Wu 6.26221e-02
#
# Level 1 Residual 5.33509e-04 Wu 6.26259e-02
#
# Level 1 Residual 1.61044e-04 Wu 6.26297e-02
#
# Level 1 Residual 6.34976e-05 Wu 6.26335e-02
#
# Level 1 Residual 3.13556e-05 Wu 6.26373e-02
#
# Level 1 Residual 1.64699e-05 Wu 6.26411e-02
#
# Level 1 Residual 8.33398e-06 Wu 6.26450e-02
#
# Level 1 Residual 4.17937e-06 Wu 6.26488e-02
#
# Level 1 Residual 2.09123e-06 Wu 6.26526e-02
#
# Level 1 Residual 1.04581e-06 Wu 6.26564e-02
#
# Level 1 Residual 5.22929e-07 Wu 6.26602e-02
#
# Level 2 Residual 5.02221e-04 Wu 6.26755e-02
#
# Level 3 Residual 1.04732e-03 Wu 6.27365e-02
#
# Level 4 Residual 1.16969e-03 Wu 6.29807e-02
#
# Level 5 Residual 1.17268e-03 Wu 6.39572e-02
#
# Level 6 Residual 1.16695e-03 Wu 6.78635e-02
#
# Level 7 Residual 1.16910e-03 Wu 8.34885e-02
#
#
#
# Level 8 Residual 2.26703e-03 Wu 1.45988e-01
#
# Level 8 Residual 2.26431e-03 Wu 2.08488e-01
#
# Level 7 Residual 2.26663e-03 Wu 2.24113e-01
#
# Level 7 Residual 2.26277e-03 Wu 2.39738e-01
#
# Level 6 Residual 2.26714e-03 Wu 2.43645e-01
#
# Level 6 Residual 2.25784e-03 Wu 2.47551e-01
#
# Level 5 Residual 2.25598e-03 Wu 2.48528e-01
#
# Level 5 Residual 2.22811e-03 Wu 2.49504e-01
#
# Level 4 Residual 2.18222e-03 Wu 2.49748e-01
#
# Level 4 Residual 2.09425e-03 Wu 2.49992e-01
#
# Level 3 Residual 1.86916e-03 Wu 2.50053e-01
#
# Level 3 Residual 1.60598e-03 Wu 2.50114e-01
#
# Level 2 Residual 9.72382e-04 Wu 2.50130e-01
#
# Level 2 Residual 5.70291e-04 Wu 2.50145e-01
#
# Level 1 Residual 1.35128e-04 Wu 2.50149e-01
#
# Level 1 Residual 4.08900e-05 Wu 2.50153e-01
#
# Level 1 Residual 1.61102e-05 Wu 2.50156e-01
#
# Level 1 Residual 7.99022e-06 Wu 2.50160e-01
#
# Level 1 Residual 4.19533e-06 Wu 2.50164e-01
#
# Level 1 Residual 2.12269e-06 Wu 2.50168e-01
#
# Level 1 Residual 1.06447e-06 Wu 2.50172e-01
#
# Level 1 Residual 5.32628e-07 Wu 2.50175e-01
#
# Level 1 Residual 2.66363e-07 Wu 2.50179e-01
#
# Level 1 Residual 1.33188e-07 Wu 2.50183e-01
#
# Level 2 Residual 1.26572e-04 Wu 2.50198e-01
#
# Level 3 Residual 2.65206e-04 Wu 2.50259e-01
#
# Level 4 Residual 2.96143e-04 Wu 2.50504e-01
#
# Level 5 Residual 2.96774e-04 Wu 2.51480e-01
#
# Level 6 Residual 2.94924e-04 Wu 2.55386e-01
#
# Level 7 Residual 2.94220e-04 Wu 2.71011e-01
#
# Level 8 Residual 2.94319e-04 Wu 3.33511e-01
#
#
#
# Level 9 Residual 5.68423e-04 Wu 5.83511e-01
#
# Level 9 Residual 5.68137e-04 Wu 8.33511e-01
#
# Level 8 Residual 5.68594e-04 Wu 8.96011e-01
#
# Level 8 Residual 5.68208e-04 Wu 9.58511e-01
#
# Level 7 Residual 5.69155e-04 Wu 9.74136e-01
#
# Level 7 Residual 5.68296e-04 Wu 9.89761e-01
#
# Level 6 Residual 5.69598e-04 Wu 9.93668e-01
#
# Level 6 Residual 5.67327e-04 Wu 9.97574e-01
#
# Level 5 Residual 5.66996e-04 Wu 9.98550e-01
#
# Level 5 Residual 5.60040e-04 Wu 9.99527e-01
#
# Level 4 Residual 5.48621e-04 Wu 9.99771e-01
#
# Level 4 Residual 5.26525e-04 Wu 1.00002e+00
#
# Level 3 Residual 4.69682e-04 Wu 1.00008e+00
#
# Level 3 Residual 4.03484e-04 Wu 1.00014e+00
#
# Level 2 Residual 2.44168e-04 Wu 1.00015e+00
#
# Level 2 Residual 1.43097e-04 Wu 1.00017e+00
#
# Level 1 Residual 3.39852e-05 Wu 1.00017e+00
#
# Level 1 Residual 1.03050e-05 Wu 1.00018e+00
#
# Level 1 Residual 4.05865e-06 Wu 1.00018e+00
#
# Level 1 Residual 2.01952e-06 Wu 1.00018e+00
#
# Level 1 Residual 1.06006e-06 Wu 1.00019e+00
#
# Level 1 Residual 5.36318e-07 Wu 1.00019e+00
#
# Level 1 Residual 2.68945e-07 Wu 1.00019e+00
#
# Level 1 Residual 1.34571e-07 Wu 1.00020e+00
#
# Level 1 Residual 6.72977e-08 Wu 1.00020e+00
#
# Level 1 Residual 3.36504e-08 Wu 1.00021e+00
#
# Level 2 Residual 3.17279e-05 Wu 1.00022e+00
#
# Level 3 Residual 6.66774e-05 Wu 1.00028e+00
#
# Level 4 Residual 7.44525e-05 Wu 1.00053e+00
#
# Level 5 Residual 7.46203e-05 Wu 1.00150e+00
#
# Level 6 Residual 7.41414e-05 Wu 1.00541e+00
#
# Level 7 Residual 7.39283e-05 Wu 1.02103e+00
#
# Level 8 Residual 7.38275e-05 Wu 1.08353e+00
#
# Level 9 Residual 7.38065e-05 Wu 1.33353e+00
#
#
#
# Level 10 Residual 1.42284e-04 Wu 2.33353e+00
#
# Level 10 Residual 1.42252e-04 Wu 3.33353e+00
#
# Level 9 Residual 1.42322e-04 Wu 3.58353e+00
#
# Level 9 Residual 1.42281e-04 Wu 3.83353e+00
#
# Level 8 Residual 1.42428e-04 Wu 3.89603e+00
#
# Level 8 Residual 1.42340e-04 Wu 3.95853e+00
#
# Level 7 Residual 1.42595e-04 Wu 3.97416e+00
#
# Level 7 Residual 1.42387e-04 Wu 3.98978e+00
#
# Level 6 Residual 1.42726e-04 Wu 3.99369e+00
#
# Level 6 Residual 1.42161e-04 Wu 3.99760e+00
#
# Level 5 Residual 1.42081e-04 Wu 3.99857e+00
#
# Level 5 Residual 1.40336e-04 Wu 3.99955e+00
#
# Level 4 Residual 1.37474e-04 Wu 3.99979e+00
#
# Level 4 Residual 1.31935e-04 Wu 4.00004e+00
#
# Level 3 Residual 1.17649e-04 Wu 4.00010e+00
#
# Level 3 Residual 1.01056e-04 Wu 4.00016e+00
#
# Level 2 Residual 6.11362e-05 Wu 4.00018e+00
#
# Level 2 Residual 3.58155e-05 Wu 4.00019e+00
#
# Level 1 Residual 8.51732e-06 Wu 4.00019e+00
#
# Level 1 Residual 2.58623e-06 Wu 4.00020e+00
#
# Level 1 Residual 1.01848e-06 Wu 4.00020e+00
#
# Level 1 Residual 5.07811e-07 Wu 4.00021e+00
#
# Level 1 Residual 2.66505e-07 Wu 4.00021e+00
#
# Level 1 Residual 1.34828e-07 Wu 4.00021e+00
#
# Level 1 Residual 6.76107e-08 Wu 4.00022e+00
#
# Level 1 Residual 3.38300e-08 Wu 4.00022e+00
#
# Level 1 Residual 1.69181e-08 Wu 4.00023e+00
#
# Level 1 Residual 8.45942e-09 Wu 4.00023e+00
#
# Level 2 Residual 7.93712e-06 Wu 4.00024e+00
#
# Level 3 Residual 1.67070e-05 Wu 4.00031e+00
#
# Level 4 Residual 1.86562e-05 Wu 4.00055e+00
#
# Level 5 Residual 1.87019e-05 Wu 4.00153e+00
#
# Level 6 Residual 1.85826e-05 Wu 4.00543e+00
#
# Level 7 Residual 1.85283e-05 Wu 4.02106e+00
#
# Level 8 Residual 1.84990e-05 Wu 4.08356e+00
#
# Level 9 Residual 1.84793e-05 Wu 4.33356e+00
#
# Level 10 Residual 1.84749e-05 Wu 5.33356e+00
#
#
#
#
# Level 10: er=5.12505956e-07
#
#
#
#
#
#  aen( 2, 1)=7.80232e-02
#
#  aen( 3, 2)=2.58351e-02
#
#  aen( 4, 3)=6.08986e-03
#
#  aen( 5, 4)=1.52324e-03
#
#  aen( 6, 5)=3.87453e-04
#
#  aen( 7, 6)=9.78512e-05
#
#  aen( 8, 7)=2.45714e-05
#
#  aen( 9, 8)=6.15099e-06
#
#  aen(10, 9)=1.53786e-06
